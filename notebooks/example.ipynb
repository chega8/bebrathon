# %%
# %load_ext autoreload

# %autoreload 2

# %% [markdown]
# ## Install repo and poetry

# %%
# !pip install -q --pre poetry

# %%
# !git clone https://git.epam.com/nikita_pavin/deddie-datathon/-/tree/main
# %cd deddie-datathon
# !poetry install

# %% [markdown]
# ## Mount gdrive and repro experiment

# %%
from google.colab import drive

drive.mount('/content/drive') # https://stackoverflow.com/questions/54351852/accessing-shared-with-me-with-colab
project_path = "/content/drive/MyDrive/DEDDIE_Datathon" # "Add shortcut to Drive" from Andrey`s google drive

# %%
# !dvc repro
